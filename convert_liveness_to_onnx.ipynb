# %%
# !pip install onnx

# %%
# !git clone https://github.com/onnx/tensorflow-onnx.git
# %cd tensorflow-onnx

download_link = 'https://github.com/biometric-technologies/liveness-detection-model/releases/download/v0.2.0/model.tflite'
tflite_path = 'model.tflite'

# !wget $download_link -O $tflite_path
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 78.7 MB/s eta 0:00:00
# ...

# %%
# !python -m tf2onnx.convert --tflite model.tflite --output model.onnx
# Out:
# 2023-11-11 14:50:43.693770: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-11 14:50:43.693856: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-11 14:50:43.693958: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-11 14:50:43.702942: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import onnx

onnx_model = onnx.load("model.onnx")
onnx.checker.check_model(onnx_model)
print(onnx.helper.printable_graph(onnx_model.graph))
# Out:
# graph tf2onnx (
#   %serving_default_input_1:0[FLOAT, unk__667x224x224x3]
# ) initializers (
#   %pad_const__136[INT64, 8]
#   %mobilenetv2_spoof/expanded_conv_project_BN/FusedBatchNormV3[FLOAT, 16]
#   %mobilenetv2_spoof/expanded_conv_depthwise_BN/FusedBatchNormV3[FLOAT, 32]
#   %mobilenetv2_spoof/dense_1/BiasAdd/ReadVariableOp[FLOAT, 64]
#   %mobilenetv2_spoof/dense/BiasAdd/ReadVariableOp[FLOAT, 128]
#   %mobilenetv2_spoof/conv2d/BiasAdd/ReadVariableOp[FLOAT, 32]
#   %mobilenetv2_spoof/classifier/BiasAdd/ReadVariableOp[FLOAT, 1]
#   %mobilenetv2_spoof/bn_Conv1/FusedBatchNormV3[FLOAT, 32]
#   %mobilenetv2_spoof/block_9_project_BN/FusedBatchNormV3[FLOAT, 64]
#   %mobilenetv2_spoof/block_9_expand_BN/FusedBatchNormV3[FLOAT, 384]
#   %mobilenetv2_spoof/block_9_depthwise_BN/FusedBatchNormV3[FLOAT, 384]
#   %mobilenetv2_spoof/block_8_project_BN/FusedBatchNormV3[FLOAT, 64]
#   %mobilenetv2_spoof/block_8_expand_BN/FusedBatchNormV3[FLOAT, 384]
# ...
